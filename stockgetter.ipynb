# %%
from yahoo_fin import stock_info as si
import time
import datetime
import mysql.connector
import settings

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="gaurav",
    database="stockprice",
    charset = 'utf8'
)
count = 0
original_price = 287.05
while True:
    if mydb.is_connected():
        mycursor = mydb.cursor()
        """mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, "price VARCHAR(255), date DATETIME"))"""
        if (count < 1):
            mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, "price VARCHAR(255), market VARCHAR(255), date DATETIME"))   
            count += 1
        sql = "INSERT INTO {} (price, market, date) VALUES (%s, %s, %s)".format(settings.TABLE_NAME)
        price = si.get_live_price("sbux")
        p= si.get_top_crypto()
        m = si.get_live_price("spy")
        i = datetime.datetime.now()
        date = ("%s" % i)
        print(time)
        market = (m-original_price)/original_price
        val = (price, market, date)
        mycursor.execute(sql,val)
        mydb.commit()
        mycursor.close()
    time.sleep(60)
# Out:
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# <module 'time' (built-in)>
# ...

# %%
original_price = 6000
while True:
    if mydb.is_connected():
        p= si.get_top_crypto()
        price = p["Price (Intraday)"][1]
        if mydb.is_connected():
            sql = "INSERT INTO {} (market) VALUES (%s)".format(settings.TABLE_NAME)
        
        val=(market)
        mycursor.execute(sql, val)
        mydb.commit()
        mycursor.close()
    sleep(60)

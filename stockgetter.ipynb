# %%
from yahoo_fin import stock_info as si
import time
import datetime
while True:
    print(si.get_live_price("aapl"))
    i = datetime.datetime.now()
    print ("Current date & time = %s" % i)
    time.sleep(30)
# Out:
# 246.8800048828125
# Current date & time = 2020-03-24 14:00:02.396266
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3205c26aac53> in <module>
#       6     i = datetime.datetime.now()
#       7     print ("Current date & time = %s" % i)
# ----> 8     time.sleep(30)
#       9
#
# KeyboardInterrupt:

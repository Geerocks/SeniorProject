# %%
from yahoo_fin import stock_info as si
import time
import datetime
import mysql.connector

import settings

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="gaurav",
    database="stockprice",
    charset = 'utf8'
)
while True:

    if mydb.is_connected():
        mycursor = mydb.cursor()
        sql = "INSERT INTO {} (price, date) VALUES (%s, %s)".format(settings.TABLE_NAME)
        price= si.get_live_price("aapl")
        i = datetime.datetime.now()
        date = ("%s" % i)
    
        val = (price, date)
        mycursor.execute(sql,val)
        mydb.commit()
        mycursor.close()
    time.sleep(30)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ae8e24193b43> in <module>
#      26         mydb.commit()
#      27         mycursor.close()
# ---> 28     time.sleep(30)
#      29
#      30
#
# KeyboardInterrupt:
